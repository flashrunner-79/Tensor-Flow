# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
from torchvision import datasets,models,transforms
import matplotlib.pyplot as plt
data_dir= r'/content/drive/MyDrive/data'

train = datasets.ImageFolder(os.path.join(data_dir,"Train"),transform = transforms.ToTensor())

train_norm = train/255
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3006/3575575627.py in <cell line: 0>()
#       6 train = datasets.ImageFolder(os.path.join(data_dir,"Train"),transform = transforms.ToTensor())
#       7
# ----> 8 train_norm = train.astype('float32')/255
#
# AttributeError: 'ImageFolder' object has no attribute 'astype'
